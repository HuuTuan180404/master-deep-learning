# %%
pwd
# Out:
# 'd:\\master\\DeepLearning\\middle_test'

# %%
with open('Locality-iN-Locality\data\GT-final_test.csv', 'r') as f:
    final_test = f.readlines()
final_test=final_test[1:]

# %% [markdown]
# ## Final training dataset
# **Path: Locality-iN-Locality\data\GTSRB\Final_Training\Images**

# %%
import os
import matplotlib.pyplot as plt

data_final_training = "Locality-iN-Locality\data\GTSRB\Final_Training\Images"
counts = []
classes = [i for i in range(43)]
for class_folder in os.listdir(data_final_training):
    count_samples = len(os.listdir(f'{data_final_training}\{class_folder}'))
    counts.append(count_samples)
    # print(f'Class {int(class_folder)}: {count_samples} samples')

print(f"{sum(counts)} training samples")

# plt.figure(figsize=(15, 6))

# plt.bar(classes, counts)

# plt.xlabel("Class ID")
# plt.ylabel("Number of Samples")
# plt.title("Number of Samples per Class on Training dataset")

# plt.xticks(classes)

# plt.show()
# Out:
# 39252 training samples

# %% [markdown]
# ## Final test dataset
# **Path: Locality-iN-Locality\data\GTSRB\Final_Test\Images**

# %%
data_final_test = "Locality-iN-Locality\data\GTSRB\Final_Test\Images"
count_test_samples = len(os.listdir(data_final_test))
print(f'{count_test_samples} test samples')
# Out:
# 12631 test samples

# %% [markdown]
# ## Test dataset
# **Path: Locality-iN-Locality\data\GTSRB\test**

# %%
data_test = "Locality-iN-Locality\data\GTSRB\\test"

count_samples = 0

for class_folder in os.listdir(data_test):
    count_class_samples = len(os.listdir(f'{data_test}\{class_folder}'))
    count_samples +=count_class_samples
    print(f'Class {class_folder}: {count_class_samples} samples')
print(f'{count_samples} test samples')
# Out:
# Class 0000: 60 samples
# Class 0001: 720 samples
# Class 0002: 750 samples
# Class 0003: 450 samples
# Class 0004: 660 samples
# Class 0005: 630 samples
# Class 0006: 150 samples
# Class 0007: 450 samples
# Class 0008: 450 samples
# Class 0009: 480 samples
# Class 0010: 660 samples
# Class 0011: 420 samples
# Class 0012: 690 samples
# Class 0013: 720 samples
# Class 0014: 270 samples
# Class 0015: 210 samples
# Class 0016: 150 samples
# Class 0017: 360 samples
# Class 0018: 390 samples
# Class 0019: 60 samples
# Class 0020: 90 samples
# Class 0021: 90 samples
# Class 0022: 120 samples
# Class 0023: 150 samples
# Class 0024: 90 samples
# Class 0025: 480 samples
# Class 0026: 180 samples
# Class 0027: 60 samples
# Class 0028: 150 samples
# Class 0029: 90 samples
# Class 0030: 150 samples
# Class 0031: 270 samples
# Class 0032: 60 samples
# Class 0033: 210 samples
# Class 0034: 120 samples
# Class 0035: 390 samples
# Class 0036: 120 samples
# Class 0037: 60 samples
# ...
